# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# %%
# Tokenize words
nltk.download("punkt")
nltk.download("stopwords")
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
with open("sample.txt", "r", encoding="utf-8") as file:
    text = file.read()

# %%
text.lower()
# Out:
# '[the adventures of buster bear by thornton w. burgess 1920]\n\ni\n\nbuster bear goes fishing\n\n\nbuster bear yawned as he lay on his comfortable bed of leaves and\nwatched the first early morning sunbeams creeping through the green\nforest to chase out the black shadows. once more he yawned, and slowly\ngot to his feet and shook himself. then he walked over to a big\npine-tree, stood up on his hind legs, reached as high up on the trunk of\nthe tree as he could, and scratched the bark with his great claws. after\nthat he yawned until it seemed as if his jaws would crack, and then sat\ndown to think what he wanted for breakfast.\n\nwhile he sat there, trying to make up his mind what would taste best, he\nwas listening to the sounds that told of the waking of all the little\npeople who live in the green forest. he heard sammy jay way off in the\ndistance screaming, "thief! thief!" and grinned. "i wonder," thought\nbuster, "if some one has stolen sammy\'s breakfast, or if he has stolen\nthe breakfast of some one else. probably he is the thief himself."\n\nhe heard chatterer the red squirrel scolding as fast as he could make\nhis tongue go and working himself into a terrible rage. "must be that\nchatterer got out of bed the wrong way this morning," thought he.\n\nhe heard blacky the crow cawing at the top of his lungs, and he knew by\nthe sound that blacky was getting into mischief of some kind. he heard\nthe sweet voices of happy little singers, and they were good to hear.\nbut most of all he listened to a merry, low, silvery laugh that never\nstopped but went on and on, until he just felt as if he must laugh too.\nit was the voice of the laughing brook. and as buster listened it\nsuddenly came to him just what he wanted for breakfast.\n\n"i\'m going fishing," said he in his deep grumbly-rumbly voice to no one\nin particular. "yes, sir, i\'m going fishing. i want some fat trout for\nmy breakfast."\n\nhe shuffled along over to the laughing brook, and straight to a little\npool of which he knew, and as he drew near he took the greatest care not\nto make the teeniest, weeniest bit of noise. now it just happened that\nearly as he was, some one was before buster bear. when he came in sight\nof the little pool, who should he see but another fisherman there, who\nhad already caught a fine fat trout. who was it? why, little joe otter\nto be sure. he was just climbing up the bank with the fat trout in his\nmouth. buster bear\'s own mouth watered as he saw it. little joe sat down\non the bank and prepared to enjoy his breakfast. he hadn\'t seen buster\nbear, and he didn\'t know that he or any one else was anywhere near.\n\nbuster bear tiptoed up very softly until he was right behind little joe\notter. "woof, woof!" said he in his deepest, most grumbly-rumbly voice.\n"that\'s a very fine looking trout. i wouldn\'t mind if i had it myself."\n\nlittle joe otter gave a frightened squeal and without even turning to\nsee who was speaking dropped his fish and dived headfirst into the\nlaughing brook. buster bear sprang forward and with one of his big paws\ncaught the fat trout just as it was slipping back into the water.\n\n"here\'s your trout, mr. otter," said he, as little joe put his head out\nof water to see who had frightened him so. "come and get it."\n\n[illustration: "here\'s your trout, mr. otter," said he. _page 5._]\n\nbut little joe wouldn\'t. the fact is, he was afraid to. he snarled at\nbuster bear and called him a thief and everything bad he could think of.\nbuster didn\'t seem to mind. he chuckled as if he thought it all a great\njoke and repeated his invitation to little joe to come and get his fish.\nbut little joe just turned his back and went off down the laughing brook\nin a great rage.\n\n"it\'s too bad to waste such a fine fish," said buster thoughtfully. "i\nwonder what i\'d better do with it." and while he was wondering, he ate\nit all up. then he started down the laughing brook to try to catch some\nfor himself.\n\n\n\n ...

# %%
test_text = "I jump to the lake"

# tokenize text
tokens = word_tokenize(text.lower())  # Lowercase for uniformity

# Remove punctuation
tokens = [word for word in tokens if word not in string.punctuation]

# # Remove stop words
stop_words = set(stopwords.words("english"))
filtered_tokens = [word for word in tokens if word not in stop_words]

# %%
# tokens = nltk.word_tokenize(text.lower())
from nltk.util import ngrams
from collections import Counter


lemmatizer = WordNetLemmatizer()
# Apply lemmatization
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

# Generate trigrams
trigrams = list(ngrams(lemmatized_tokens, 3))

# Count trigram frequency
trigram_freq = Counter(trigrams)

# Function to predict next word
def predict_next_word(word1, word2):
    predictions = {trigram[2]: count for trigram, count in trigram_freq.items() if trigram[0] == word1 and trigram[1] == word2}
    return max(predictions, key=predictions.get) if predictions else None

# %%
# Example usage
word1, word2 = "first", "early"
next_word = predict_next_word(word1, word2)
print(f"Predicted next word: {next_word}")
# Out:
# Predicted next word: morning

# %%
text
# Out:
# '[The Adventures of Buster Bear by Thornton W. Burgess 1920]\n\nI\n\nBUSTER BEAR GOES FISHING\n\n\nBuster Bear yawned as he lay on his comfortable bed of leaves and\nwatched the first early morning sunbeams creeping through the Green\nForest to chase out the Black Shadows. Once more he yawned, and slowly\ngot to his feet and shook himself. Then he walked over to a big\npine-tree, stood up on his hind legs, reached as high up on the trunk of\nthe tree as he could, and scratched the bark with his great claws. After\nthat he yawned until it seemed as if his jaws would crack, and then sat\ndown to think what he wanted for breakfast.\n\nWhile he sat there, trying to make up his mind what would taste best, he\nwas listening to the sounds that told of the waking of all the little\npeople who live in the Green Forest. He heard Sammy Jay way off in the\ndistance screaming, "Thief! Thief!" and grinned. "I wonder," thought\nBuster, "if some one has stolen Sammy\'s breakfast, or if he has stolen\nthe breakfast of some one else. Probably he is the thief himself."\n\nHe heard Chatterer the Red Squirrel scolding as fast as he could make\nhis tongue go and working himself into a terrible rage. "Must be that\nChatterer got out of bed the wrong way this morning," thought he.\n\nHe heard Blacky the Crow cawing at the top of his lungs, and he knew by\nthe sound that Blacky was getting into mischief of some kind. He heard\nthe sweet voices of happy little singers, and they were good to hear.\nBut most of all he listened to a merry, low, silvery laugh that never\nstopped but went on and on, until he just felt as if he must laugh too.\nIt was the voice of the Laughing Brook. And as Buster listened it\nsuddenly came to him just what he wanted for breakfast.\n\n"I\'m going fishing," said he in his deep grumbly-rumbly voice to no one\nin particular. "Yes, Sir, I\'m going fishing. I want some fat trout for\nmy breakfast."\n\nHe shuffled along over to the Laughing Brook, and straight to a little\npool of which he knew, and as he drew near he took the greatest care not\nto make the teeniest, weeniest bit of noise. Now it just happened that\nearly as he was, some one was before Buster Bear. When he came in sight\nof the little pool, who should he see but another fisherman there, who\nhad already caught a fine fat trout. Who was it? Why, Little Joe Otter\nto be sure. He was just climbing up the bank with the fat trout in his\nmouth. Buster Bear\'s own mouth watered as he saw it. Little Joe sat down\non the bank and prepared to enjoy his breakfast. He hadn\'t seen Buster\nBear, and he didn\'t know that he or any one else was anywhere near.\n\nBuster Bear tiptoed up very softly until he was right behind Little Joe\nOtter. "Woof, woof!" said he in his deepest, most grumbly-rumbly voice.\n"That\'s a very fine looking trout. I wouldn\'t mind if I had it myself."\n\nLittle Joe Otter gave a frightened squeal and without even turning to\nsee who was speaking dropped his fish and dived headfirst into the\nLaughing Brook. Buster Bear sprang forward and with one of his big paws\ncaught the fat trout just as it was slipping back into the water.\n\n"Here\'s your trout, Mr. Otter," said he, as Little Joe put his head out\nof water to see who had frightened him so. "Come and get it."\n\n[Illustration: "Here\'s your trout, Mr. Otter," said he. _Page 5._]\n\nBut Little Joe wouldn\'t. The fact is, he was afraid to. He snarled at\nBuster Bear and called him a thief and everything bad he could think of.\nBuster didn\'t seem to mind. He chuckled as if he thought it all a great\njoke and repeated his invitation to Little Joe to come and get his fish.\nBut Little Joe just turned his back and went off down the Laughing Brook\nin a great rage.\n\n"It\'s too bad to waste such a fine fish," said Buster thoughtfully. "I\nwonder what I\'d better do with it." And while he was wondering, he ate\nit all up. Then he started down the Laughing Brook to try to catch some\nfor himself.\n\n\n\n ...

# %% [markdown]
# ### Trial Using Australian Broadcasting Commission 2006

# %%
with open("new_science.txt", "r", encoding="utf-8") as file:
    text_science = file.read()

# %%
import re

# tokenize text
def tokenization(text):
    tokens = word_tokenize(text.lower())  # Lowercase for uniformity

    # Remove punctuation
    tokens = [word for word in tokens if word not in string.punctuation]

    # # Remove stop words
    stop_words = set(stopwords.words("english"))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    lemmatizer = WordNetLemmatizer()
    # Apply lemmatization
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

    return(lemmatized_tokens)

# tokenize with punctuation remove first
def modif_tokenization(text):
    pre_text = text.lower()
    #Remove punctuation using regular expressions
    text_no_punctuation = re.sub(r'[^\w\s]', '', pre_text)

    tokens = word_tokenize(text_no_punctuation.strip())  # Lowercase for uniformity

    # # Remove stop words
    stop_words = set(stopwords.words("english"))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    lemmatizer = WordNetLemmatizer()
    # Apply lemmatization
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

    return(lemmatized_tokens)

# Function to predict next word
def predict_next(word1, word2):
    predictions = {trigram[2]: count for trigram, count in trigram_freq.items() if trigram[0] == word1 and trigram[1] == word2}
    return max(predictions, key=predictions.get) if predictions else None



token_lemma = tokenization(text)
n_for_gram = 3

# Generate trigrams
trigrams = list(ngrams(lemmatized_tokens, n_for_gram))

# Count trigram frequency
trigram_freq = Counter(trigrams)

# %%
trigram_freq.keys()
# Out:
# dict_keys([('adventure', 'buster', 'bear'), ('buster', 'bear', 'thornton'), ('bear', 'thornton', 'w.'), ('thornton', 'w.', 'burgess'), ('w.', 'burgess', '1920'), ('burgess', '1920', 'buster'), ('1920', 'buster', 'bear'), ('buster', 'bear', 'go'), ('bear', 'go', 'fishing'), ('go', 'fishing', 'buster'), ('fishing', 'buster', 'bear'), ('buster', 'bear', 'yawned'), ('bear', 'yawned', 'lay'), ('yawned', 'lay', 'comfortable'), ('lay', 'comfortable', 'bed'), ('comfortable', 'bed', 'leaf'), ('bed', 'leaf', 'watched'), ('leaf', 'watched', 'first'), ('watched', 'first', 'early'), ('first', 'early', 'morning'), ('early', 'morning', 'sunbeam'), ('morning', 'sunbeam', 'creeping'), ('sunbeam', 'creeping', 'green'), ('creeping', 'green', 'forest'), ('green', 'forest', 'chase'), ('forest', 'chase', 'black'), ('chase', 'black', 'shadow'), ('black', 'shadow', 'yawned'), ('shadow', 'yawned', 'slowly'), ('yawned', 'slowly', 'got'), ('slowly', 'got', 'foot'), ('got', 'foot', 'shook'), ('foot', 'shook', 'walked'), ('shook', 'walked', 'big'), ('walked', 'big', 'pine-tree'), ('big', 'pine-tree', 'stood'), ('pine-tree', 'stood', 'hind'), ('stood', 'hind', 'leg'), ('hind', 'leg', 'reached'), ('leg', 'reached', 'high'), ('reached', 'high', 'trunk'), ('high', 'trunk', 'tree'), ('trunk', 'tree', 'could'), ('tree', 'could', 'scratched'), ('could', 'scratched', 'bark'), ('scratched', 'bark', 'great'), ('bark', 'great', 'claw'), ('great', 'claw', 'yawned'), ('claw', 'yawned', 'seemed'), ('yawned', 'seemed', 'jaw'), ('seemed', 'jaw', 'would'), ('jaw', 'would', 'crack'), ('would', 'crack', 'sat'), ('crack', 'sat', 'think'), ('sat', 'think', 'wanted'), ('think', 'wanted', 'breakfast'), ('wanted', 'breakfast', 'sat'), ('breakfast', 'sat', 'trying'), ('sat', 'trying', 'make'), ('trying', 'make', 'mind'), ('make', 'mind', 'would'), ('mind', 'would', 'taste'), ('would', 'taste', 'best'), ('taste', 'best', 'listening'), ('best', 'listening', 'sound'), ('listening', 'sound', 'told'), ('sound', 'told', 'waking'), ('told', 'waking', 'little'), ('waking', 'little', 'people'), ('little', 'people', 'live'), ('people', 'live', 'green'), ('live', 'green', 'forest'), ('green', 'forest', 'heard'), ('forest', 'heard', 'sammy'), ('heard', 'sammy', 'jay'), ('sammy', 'jay', 'way'), ('jay', 'way', 'distance'), ('way', 'distance', 'screaming'), ('distance', 'screaming', '``'), ('screaming', '``', 'thief'), ('``', 'thief', 'thief'), ('thief', 'thief', "''"), ('thief', "''", 'grinned'), ("''", 'grinned', '``'), ('grinned', '``', 'wonder'), ('``', 'wonder', "''"), ('wonder', "''", 'thought'), ("''", 'thought', 'buster'), ('thought', 'buster', '``'), ('buster', '``', 'one'), ('``', 'one', 'stolen'), ('one', 'stolen', 'sammy'), ('stolen', 'sammy', "'s"), ('sammy', "'s", 'breakfast'), ("'s", 'breakfast', 'stolen'), ('breakfast', 'stolen', 'breakfast'), ('stolen', 'breakfast', 'one'), ('breakfast', 'one', 'else'), ('one', 'else', 'probably'), ('else', 'probably', 'thief'), ('probably', 'thief', "''"), ('thief', "''", 'heard'), ("''", 'heard', 'chatterer'), ('heard', 'chatterer', 'red'), ('chatterer', 'red', 'squirrel'), ('red', 'squirrel', 'scolding'), ('squirrel', 'scolding', 'fast'), ('scolding', 'fast', 'could'), ('fast', 'could', 'make'), ('could', 'make', 'tongue'), ('make', 'tongue', 'go'), ('tongue', 'go', 'working'), ('go', 'working', 'terrible'), ('working', 'terrible', 'rage'), ('terrible', 'rage', '``'), ('rage', '``', 'must'), ('``', 'must', 'chatterer'), ('must', 'chatterer', 'got'), ('chatterer', 'got', 'bed'), ('got', 'bed', 'wrong'), ('bed', 'wrong', 'way'), ('wrong', 'way', 'morning'), ('way', 'morning', "''"), ('morning', "''", 'thought'), ("''", 'thought', 'heard'), ('thought', 'heard', 'blacky'), ('heard', 'blacky', 'crow'), ('blacky', 'crow', 'cawing'), ('crow', 'cawing', 'top'), ('cawing', 'top', 'lung'), ('top', 'lung', 'knew'), ('lung', 'knew', 'sound'), ('knew', 'sound', 'blacky'), ('sound', 'blacky', 'getting'), ('blacky', 'getting', 'mischief'), ('getting', 'mis ...

# %%
w1 = 'adventure'
w2 = 'buster'

# x = trigram_freq.get((w1, w2), {})
# x

x = {trigram[2]: count for trigram, count in trigram_freq.items() if trigram[0] == w1 and trigram[1] == w2}
print(x)
# Out:
# {'bear': 2}

# %%
def predict_next_word(w1,w2,trigram_freq):
    result = dict()

    for val in trigram_freq.items():
        item = val[0]
        freq = val[1]

        if item[0] == w1 and item[1] == w2:
            result[item] = freq
        # print(val[2])

    if not result : 
        return(None)
    else:
        max_key = max(result, key=lambda k: result[k])
        
        return(max_key[2])

# %%
predict_next_word('adventure', 'buster', trigram_freq)
# Out:
# 'bear'

# %%
# test schema with random value
import random
iteration_number = 10

def randomizers(iteration_number, max_num):
    list_random = []

    for i in range(iteration_number):
        rand_numbers = random.randint(0, max_num)
        list_random.append(rand_numbers)
    
    return(list_random)

def testing_word_prediction(trigrams, trigram_freq, iteration_number, list_random, detail=False):
    final_score = 0
    
    for i in range (iteration_number):
        score = 0

        # print(trigrams[rand_numbers])
        value = trigrams[list_random[i]]

        next_word = predict_next_word(value[0], value[1], trigram_freq)

        if detail:
            print('predict next word: {}'.format(next_word))

        if (next_word == value[2]):
            if detail:
                print('true')
                print()
            
            score = 1
        else :
            if detail:
                print('false')
                print()
        
        final_score += score

    return(final_score)

list_randoms = randomizers(iteration_number, len(trigrams))
final_score = testing_word_prediction(trigrams, trigram_freq, iteration_number, list_randoms)
print('score : {}'.format(final_score))
print('percentage true : {}'.format(final_score*100.00/iteration_number))
# Out:
# score : 9
# percentage true : 90.0

# %%
def batch_test(trigrams, trigram_freq, batch, iteration_number, rand_list, detail=False):
    list_score = []

    for i in range(batch):
        final_score = testing_word_prediction(trigrams, trigram_freq, iteration_number, rand_list[i], detail)
        list_score.append(final_score)
    
    return(list_score)

# %%
# pipeline builder 1

token_lemma = tokenization(text)
n_for_gram = 3

# Generate trigrams
trigrams = list(ngrams(token_lemma, n_for_gram))

# Count trigram frequency
trigram_freq = Counter(trigrams)

iteration_number = 50
batch = 10

random_batch = []

for i in range(batch):
    random_batch.append(randomizers(iteration_number, len(trigrams)))

list_test_score = batch_test(trigrams, trigram_freq,batch, iteration_number, random_batch)
print(list_test_score)
print('avg score : {}'.format(np.mean(list_test_score)))
print('percentage true : {}'.format(np.mean([x*100.00 / (iteration_number) for x in list_test_score])))
# Out:
# [41, 38, 42, 42, 37, 42, 37, 41, 40, 37]
# avg score : 39.7
# percentage true : 79.4

# %%
# pipeline builder 1

token_lemma_modif = modif_tokenization(text)
n_for_gram = 3

# Generate trigrams
trigrams_modif = list(ngrams(token_lemma_modif, n_for_gram))

# Count trigram frequency
trigram_freq_modif = Counter(trigrams_modif)

iteration_number = 50
batch = 10

random_batch = []

for i in range(batch):
    random_batch.append(randomizers(iteration_number, len(trigrams_modif)))

list_test_score = batch_test(trigrams_modif, trigram_freq_modif,batch, iteration_number, random_batch)
print(list_test_score)
print('avg score : {}'.format(np.mean(list_test_score)))
print('percentage true : {}'.format(np.mean([x*100.00 / iteration_number for x in list_test_score])))
# Out:
# [42, 41, 45, 45, 40, 47, 42, 40, 39, 40]
# avg score : 42.1
# percentage true : 84.2

# %%
len(trigrams)
# Out:
# 7803
